# %% [markdown]
# **Reporte python_basic_1**

# %% [markdown]
# Ya he tenido la oportunidad de trabajar mucho con python desde hace varios semestres, entonces la sintaxis y el elnguaje en general lo conozco bien.
# También he trabajado con la librería pandas, conocía de su uso para almacenar información de un .csv por ejemplo, al igual que la posibilidad de visualizar la información en forma de gráficos. Algunas funciones como *describe()* no las conocía.

# %% [markdown]
# **Reporte python_basic_2**

# %% [markdown]
# Ya conocía la librería numpy y he trabajado con ella en trabajos de otros cursos, pero no conocía de la librería scipy.

# %% [markdown]
# **Reporte python_charts**

# %% [markdown]
# Ya he tenido la oportunidad de tener que graficar conjuntos de datos para realizar análisis, inferencias, etc. El código del *basemap* me dio un error, pero buscando referencias en Google, es un tipo de gráficos que no conocía que se podía realizar con librerías en python.
